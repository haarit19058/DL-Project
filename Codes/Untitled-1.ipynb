# %%
! pip install unsloth trl datasets transformers bitsandbytes accelerate vllm
! pip install -U transformers trl huggingface_hub mergekit
! pip install flashinfer-cubin==0.6.4
# Out:
# Collecting unsloth
#   Downloading unsloth-2026.4.4-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.7 MB/s eta 0:00:00
# Collecting trl
#   Downloading trl-1.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Collecting vllm
#   Downloading vllm-0.19.0-cp38-abi3-manylinux_2_31_x86_64.whl.metadata (10.0 kB)
# Collecting unsloth_zoo>=2026.4.3 (from unsloth)
#   Downloading unsloth_zoo-2026.4.6-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.46.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (26.0)
# Requirement already satisfied: torch<2.11.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.25.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.9.5)
# Collecting tyro (from unsloth)
#   Downloading tyro-1.0.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.29.6)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.2.1)
# Collecting datasets
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.18.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.8.0)
# Collecting hf_transfer (from unsloth)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.37.1)
# Collecting transformers
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting trl
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.24.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from unsloth) (6.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.25.2)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm) (6.2.6)
# Collecting blake3 (from vllm)
#   Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm) (9.0.0)
# Collecting transformers
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.135.2)
# Requirement already satisfied: aiohttp>=3.13.3 in /usr/local/lib/python3.12/dist-packages (from vllm) (3.13.4)
# Requirement already satisfied: openai>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.30.0)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.24.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm) (11.3.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (0.12.0)
# Collecting lm-format-enforcer==0.11.3 (from vllm)
#   Downloading lm_format_enforcer-0.11.3-py3-none-any.whl.metadata (17 kB)
# Collecting llguidance<1.4.0,>=1.3.0 (from vllm)
#   Downloading llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting outlines_core==0.2.11 (from vllm)
#   Downloading outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting diskcache==5.6.3 (from vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting lark==1.2.2 (from vllm)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar<1.0.0,>=0.1.32 (from vllm)
#   Downloading xgrammar-0.1.33-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.15.0)
# Collecting partial-json-parser (from vllm)
#   Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (26.2.1)
# Collecting msgspec (from vllm)
#   Downloading msgspec-0.21.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting gguf>=0.17.0 (from vllm)
#   Downloading gguf-0.18.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting mistral_common>=1.10.0 (from mistral_common[image]>=1.10.0->vllm)
#   Downloading mistral_common-1.11.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: opencv-python-headless>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (4.13.0.92)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.17.0)
# Collecting setuptools<81.0.0,>=77.0.3 (from vllm)
#   Downloading setuptools-80.10.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm) (0.8.2)
# Collecting compressed-tensors==0.14.0.1 (from vllm)
#   Downloading compressed_tensors-0.14.0.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting depyf==0.20.0 (from vllm)
#   Downloading depyf-0.20.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm) (3.1.2)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm) (1.1.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm) (4.1.0)
# Collecting ninja (from vllm)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pybase64 (from vllm)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting cbor2 (from vllm)
#   Downloading cbor2-5.9.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting ijson (from vllm)
#   Downloading ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting setproctitle (from vllm)
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Collecting openai-harmony>=0.0.3 (from vllm)
#   Downloading openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Collecting anthropic>=0.71.0 (from vllm)
#   Downloading anthropic-0.94.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting model-hosting-container-standards<1.0.0,>=0.1.13 (from vllm)
#   Downloading model_hosting_container_standards-0.1.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: mcp in /usr/local/lib/python3.12/dist-packages (from vllm) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.38.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (1.38.0)
# Collecting opentelemetry-exporter-otlp>=1.27.0 (from vllm)
#   Downloading opentelemetry_exporter_otlp-1.41.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions-ai>=0.4.1 (from vllm)
#   Downloading opentelemetry_semantic_conventions_ai-0.5.1-py3-none-any.whl.metadata (997 bytes)
# Collecting numba==0.61.2 (from vllm)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: torchaudio==2.10.0 in /usr/local/lib/python3.12/dist-packages (from vllm) (2.10.0+cu128)
# Collecting flashinfer-python==0.6.6 (from vllm)
#   Downloading flashinfer_python-0.6.6-py3-none-any.whl.metadata (11 kB)
# Collecting flashinfer-cubin==0.6.6 (from vllm)
#   Downloading flashinfer_cubin-0.6.6-py3-none-any.whl.metadata (1.3 kB)
# Collecting nvidia-cudnn-frontend<1.19.0,>=1.13.0 (from vllm)
#   Downloading nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Collecting nvidia-cutlass-dsl>=4.4.0.dev1 (from vllm)
#   Downloading nvidia_cutlass_dsl-4.5.0.dev0-py3-none-any.whl.metadata (2.8 kB)
# Collecting quack-kernels>=0.2.7 (from vllm)
#   Downloading quack_kernels-0.3.9-py3-none-any.whl.metadata (618 bytes)
# Collecting loguru (from compressed-tensors==0.14.0.1->vllm)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting astor (from depyf==0.20.0->vllm)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting apache-tvm-ffi!=0.1.8,!=0.1.8.post0,<0.2,>=0.1.6 (from flashinfer-python==0.6.6->vllm)
#   Downloading apache_tvm_ffi-0.1.10-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.6->vllm) (8.3.1)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.6->vllm) (13.595.45)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.6->vllm) (0.9.0)
# Collecting interegular>=0.3.2 (from lm-format-enforcer==0.11.3->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba==0.61.2->vllm)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.4.0->unsloth) (1.5.0)
# Collecting huggingface_hub>=0.34.0 (from unsloth)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm) (1.23.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm) (1.3.1)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.0.4)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastapi_cli-0.0.24-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.22)
# Collecting email-validator>=2.0.0 (from fastapi[standard]>=0.115.0->vllm)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.42.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm) (2.13.1)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[standard]>=0.115.0->vllm)
#   Downloading pydantic_extra_types-2.11.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.4.2)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.10.0->mistral_common[image]>=1.10.0->vllm) (4.26.0)
# Collecting jmespath (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting supervisor>=4.2.0 (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm)
#   Downloading supervisor-4.3.0-py2.py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 9.5 MB/s eta 0:00:00
# Collecting nvidia-cutlass-dsl-libs-base==4.5.0.dev0 (from nvidia-cutlass-dsl>=4.4.0.dev1->vllm)
#   Downloading nvidia_cutlass_dsl_libs_base-4.5.0.dev0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: cuda-python>=12.8 in /usr/local/lib/python3.12/dist-packages (from nvidia-cutlass-dsl-libs-base==4.5.0.dev0->nvidia-cutlass-dsl>=4.4.0.dev1->vllm) (12.9.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->vllm) (8.7.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.41.0 (from opentelemetry-exporter-otlp>=1.27.0->vllm)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.41.0 (from opentelemetry-exporter-otlp>=1.27.0->vllm)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.41.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.41.0->opentelemetry-exporter-otlp>=1.27.0->vllm) (1.73.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.41.0->opentelemetry-exporter-otlp>=1.27.0->vllm) (1.80.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.0 (from opentelemetry-exporter-otlp-proto-grpc==1.41.0->opentelemetry-exporter-otlp>=1.27.0->vllm)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.41.0 (from opentelemetry-exporter-otlp-proto-grpc==1.41.0->opentelemetry-exporter-otlp>=1.27.0->vllm)
#   Downloading opentelemetry_proto-1.41.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.27.0 (from vllm)
#   Downloading opentelemetry_sdk-1.41.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-api>=1.27.0 (from vllm)
#   Downloading opentelemetry_api-1.41.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.62b0 (from opentelemetry-sdk>=1.27.0->vllm)
#   Downloading opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth) (2.41.4)
# Collecting torch-c-dlpack-ext (from quack-kernels>=0.2.7->vllm)
#   Downloading torch_c_dlpack_ext-0.1.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.4.3->unsloth)
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.4.3->unsloth)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm) (0.4.3)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm) (2.12.1)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm) (3.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth) (13.9.4)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (4.5.1)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading rich_toolkit-0.19.7-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastapi_cloud_cli-0.16.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->vllm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.10.0->mistral_common[image]>=1.10.0->vllm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.10.0->mistral_common[image]>=1.10.0->vllm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.10.0->mistral_common[image]>=1.10.0->vllm) (0.30.0)
# Collecting pycountry>=23 (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.10.0->mistral_common[image]>=1.10.0->vllm)
#   Downloading pycountry-26.2.16-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->fastapi[standard]>=0.115.0->vllm) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm) (43.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->unsloth) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->unsloth) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm) (2.0.0)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (2.57.0)
# Collecting fastar>=0.10.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm)
#   Downloading fastar-0.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->unsloth) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm) (3.0)
# Downloading unsloth-2026.4.4-py3-none-any.whl (62.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 14.8 MB/s eta 0:00:00:00:0100:01
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 35.4 MB/s eta 0:00:00
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 50.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.0 MB/s eta 0:00:0000:01m00:01
# Downloading vllm-0.19.0-cp38-abi3-manylinux_2_31_x86_64.whl (432.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.3/432.3 MB 3.2 MB/s eta 0:00:00:00:0100:01
# Downloading compressed_tensors-0.14.0.1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 kB 19.2 MB/s eta 0:00:00
# Downloading depyf-0.20.0-py3-none-any.whl (39 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.4 MB/s eta 0:00:00
# Downloading flashinfer_cubin-0.6.6-py3-none-any.whl (267.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.7/267.7 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Downloading flashinfer_python-0.6.6-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.8 MB/s eta 0:00:00:00:0100:01
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.0 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.11.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.4 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 92.2 MB/s eta 0:00:00:00:01
# Downloading outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 82.0 MB/s eta 0:00:00
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 98.9 MB/s eta 0:00:00:00:010:01
# Downloading anthropic-0.94.0-py3-none-any.whl (627 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 47.7 MB/s eta 0:00:00
# Downloading gguf-0.18.0-py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 11.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 42.4 MB/s eta 0:00:00
# Downloading llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 92.7 MB/s eta 0:00:00
# Downloading mistral_common-1.11.0-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 102.7 MB/s eta 0:00:00a 0:00:01
# Downloading model_hosting_container_standards-0.1.14-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.4 MB/s eta 0:00:00
# Downloading nvidia_cutlass_dsl-4.5.0.dev0-py3-none-any.whl (10 kB)
# Downloading nvidia_cutlass_dsl_libs_base-4.5.0.dev0-cp312-cp312-manylinux_2_28_x86_64.whl (74.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 9.7 MB/s eta 0:00:000:00:0100:01
# Downloading openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.9 MB/s eta 0:00:00:00:01
# Downloading opentelemetry_exporter_otlp-1.41.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.41.0-py3-none-any.whl (22 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.41.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.41.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 6.5 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.41.0-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 18.3 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.41.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 24.7 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions_ai-0.5.1-py3-none-any.whl (11 kB)
# Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (19 kB)
# Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 16.3 MB/s eta 0:00:00:00:0100:01
# Downloading quack_kernels-0.3.9-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 16.9 MB/s eta 0:00:00
# Downloading setuptools-80.10.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.9 MB/s eta 0:00:00
# Downloading unsloth_zoo-2026.4.6-py3-none-any.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 39.3 MB/s eta 0:00:00
# Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 89.4 MB/s eta 0:00:00:00:01
# Downloading xgrammar-0.1.33-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (42.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 19.3 MB/s eta 0:00:00:00:0100:01
# Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 33.1 MB/s eta 0:00:00
# Downloading cbor2-5.9.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 28.6 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 103.8 MB/s eta 0:00:0000:01
# Downloading ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 16.8 MB/s eta 0:00:00
# Downloading msgspec-0.21.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 22.8 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 17.7 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post7-py3-none-any.whl (10 kB)
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.2 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Downloading tyro-1.0.12-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 18.9 MB/s eta 0:00:00
# Downloading apache_tvm_ffi-0.1.10-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 92.3 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading fastapi_cli-0.0.24-py3-none-any.whl (12 kB)
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 19.4 MB/s eta 0:00:00:00:0100:01
# Downloading pydantic_extra_types-2.11.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 8.5 MB/s eta 0:00:00
# Downloading supervisor-4.3.0-py2.py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 31.0 MB/s eta 0:00:00
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 91.5 MB/s eta 0:00:00:00:01
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.3 MB/s eta 0:00:00
# Downloading torch_c_dlpack_ext-0.1.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.8/897.8 kB 49.5 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 30.8 MB/s eta 0:00:00
# Downloading fastapi_cloud_cli-0.16.1-py3-none-any.whl (33 kB)
# Downloading pycountry-26.2.16-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 111.0 MB/s eta 0:00:0000:0100:01
# Downloading rich_toolkit-0.19.7-py3-none-any.whl (32 kB)
# Downloading fastar-0.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 60.7 MB/s eta 0:00:00
# Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 65.3 MB/s eta 0:00:00
# Installing collected packages: torchao, supervisor, setuptools, setproctitle, rignore, pycountry, pybase64, pyarrow, partial-json-parser, outlines_core, opentelemetry-proto, nvidia-cudnn-frontend, ninja, msgspec, loguru, llvmlite, llguidance, lark, jmespath, interegular, ijson, hf_transfer, flashinfer-cubin, fastar, dnspython, diskcache, cbor2, blake3, astor, apache-tvm-ffi, tyro, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, numba, huggingface_hub, gguf, email-validator, depyf, rich-toolkit, pydantic-extra-types, prometheus-fastapi-instrumentator, opentelemetry-semantic-conventions, openai-harmony, nvidia-cutlass-dsl-libs-base, lm-format-enforcer, anthropic, xformers, transformers, torch-c-dlpack-ext, opentelemetry-sdk, nvidia-cutlass-dsl, model-hosting-container-standards, fastapi-cloud-cli, fastapi-cli, datasets, cut_cross_entropy, bitsandbytes, xgrammar, trl, quack-kernels, opentelemetry-semantic-conventions-ai, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mistral_common, flashinfer-python, compressed-tensors, unsloth_zoo, opentelemetry-exporter-otlp, unsloth, vllm
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
#     Uninstalling opentelemetry-proto-1.38.0:
#       Successfully uninstalled opentelemetry-proto-1.38.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lark
#     Found existing installation: lark 1.3.1
#     Uninstalling lark-1.3.1:
#       Successfully uninstalled lark-1.3.1
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.38.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.38.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.38.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.38.0
#     Uninstalling opentelemetry-api-1.38.0:
#       Successfully uninstalled opentelemetry-api-1.38.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.8.0
#     Uninstalling huggingface_hub-1.8.0:
#       Successfully uninstalled huggingface_hub-1.8.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.59b0
#     Uninstalling opentelemetry-semantic-conventions-0.59b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.59b0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.38.0
#     Uninstalling opentelemetry-sdk-1.38.0:
#       Successfully uninstalled opentelemetry-sdk-1.38.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-http
#     Found existing installation: opentelemetry-exporter-otlp-proto-http 1.38.0
#     Uninstalling opentelemetry-exporter-otlp-proto-http-1.38.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-http-1.38.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.0 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.0 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.0 which is incompatible.
# Successfully installed anthropic-0.94.0 apache-tvm-ffi-0.1.10 astor-0.8.1 bitsandbytes-0.49.2 blake3-1.0.8 cbor2-5.9.0 compressed-tensors-0.14.0.1 cut_cross_entropy-25.1.1 datasets-4.3.0 depyf-0.20.0 diskcache-5.6.3 dnspython-2.8.0 email-validator-2.3.0 fastapi-cli-0.0.24 fastapi-cloud-cli-0.16.1 fastar-0.10.0 flashinfer-cubin-0.6.6 flashinfer-python-0.6.6 gguf-0.18.0 hf_transfer-0.1.9 huggingface_hub-0.36.2 ijson-3.5.0 interegular-0.3.3 jmespath-1.1.0 lark-1.2.2 llguidance-1.3.0 llvmlite-0.44.0 lm-format-enforcer-0.11.3 loguru-0.7.3 mistral_common-1.11.0 model-hosting-container-standards-0.1.14 msgspec-0.21.0 ninja-1.13.0 numba-0.61.2 nvidia-cudnn-frontend-1.18.0 nvidia-cutlass-dsl-4.5.0.dev0 nvidia-cutlass-dsl-libs-base-4.5.0.dev0 openai-harmony-0.0.8 opentelemetry-api-1.41.0 opentelemetry-exporter-otlp-1.41.0 opentelemetry-exporter-otlp-proto-common-1.41.0 opentelemetry-exporter-otlp-proto-grpc-1.41.0 opentelemetry-exporter-otlp-proto-http-1.41.0 opentelemetry-proto-1.41.0 opentelemetry-sdk-1.41.0 opentelemetry-semantic-conventions-0.62b0 opentelemetry-semantic-conventions-ai-0.5.1 outlines_core-0.2.11 partial-json-parser-0.2.1.1.post7 prometheus-fastapi-instrumentator-7.1.0 pyarrow-23.0.1 pybase64-1.4.3 pycountry-26.2.16 pydantic-extra-types-2.11.2 quack-kernels-0.3.9 rich-toolkit-0.19.7 rignore-0.7.6 setproctitle-1.3.7 setuptools-80.10.2 supervisor-4.3.0 torch-c-dlpack-ext-0.1.5 torchao-0.17.0 transformers-4.57.6 trl-0.24.0 tyro-1.0.12 unsloth-2026.4.4 unsloth_zoo-2026.4.6 vllm-0.19.0 xformers-0.0.35 xgrammar-0.1.33
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Collecting transformers
#   Downloading transformers-5.5.3-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.24.0)
# Collecting trl
#   Using cached trl-1.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.2)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.10.1-py3-none-any.whl.metadata (14 kB)
# Collecting mergekit
#   Downloading mergekit-0.1.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from trl) (1.13.0)
# Collecting datasets>=4.7.0 (from trl)
#   Downloading datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface_hub)
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mergekit) (2.10.0+cu128)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.6 MB/s eta 0:00:00
# Collecting click==8.2.1 (from mergekit)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting accelerate>=1.4.0 (from trl)
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting pydantic~=2.10.6 (from mergekit)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting immutables==0.21 (from mergekit)
#   Downloading immutables-0.21-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from mergekit) (0.18.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from mergekit) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from mergekit) (5.29.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mergekit) (1.16.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.7.0->trl) (0.70.16)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.10.6->mergekit) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic~=2.10.6->mergekit)
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->mergekit) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->mergekit) (1.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (3.13.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.7.0->trl) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->mergekit) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->mergekit) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.7.0->trl) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.7.0->trl) (1.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.7.0->trl) (1.17.0)
# Downloading transformers-5.5.3-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 82.3 MB/s eta 0:00:00:00:010:01
# Downloading trl-1.0.0-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.8/630.8 kB 52.5 MB/s eta 0:00:00
# Downloading huggingface_hub-1.10.1-py3-none-any.whl (642 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.6/642.6 kB 50.6 MB/s eta 0:00:00
# Downloading mergekit-0.1.4-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.2 MB/s eta 0:00:00
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 12.2 MB/s eta 0:00:00
# Downloading immutables-0.21-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 12.1 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.5 MB/s eta 0:00:00
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 36.3 MB/s eta 0:00:00
# Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 46.8 MB/s eta 0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 133.9 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 45.7 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 104.2 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 40.0 MB/s eta 0:00:00
# Installing collected packages: tqdm, safetensors, pydantic-core, immutables, hf-xet, click, pydantic, huggingface_hub, datasets, accelerate, transformers, trl, mergekit
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.4.2
#     Uninstalling hf-xet-1.4.2:
#       Successfully uninstalled hf-xet-1.4.2
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.3.0
#     Uninstalling datasets-4.3.0:
#       Successfully uninstalled datasets-4.3.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.13.0
#     Uninstalling accelerate-1.13.0:
#       Successfully uninstalled accelerate-1.13.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.6
#     Uninstalling transformers-4.57.6:
#       Successfully uninstalled transformers-4.57.6
#   Attempting uninstall: trl
#     Found existing installation: trl 0.24.0
#     Uninstalling trl-0.24.0:
#       Successfully uninstalled trl-0.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth 2026.4.4 requires datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1, but you have datasets 4.8.4 which is incompatible.
# unsloth 2026.4.4 requires transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3, but you have transformers 5.5.3 which is incompatible.
# unsloth 2026.4.4 requires trl!=0.19.0,<=0.24.0,>=0.18.2, but you have trl 1.0.0 which is incompatible.
# compressed-tensors 0.14.0.1 requires transformers<5.0.0, but you have transformers 5.5.3 which is incompatible.
# vllm 0.19.0 requires pydantic>=2.12.0, but you have pydantic 2.10.6 which is incompatible.
# vllm 0.19.0 requires transformers<5,>=4.56.0, but you have transformers 5.5.3 which is incompatible.
# openai-harmony 0.0.8 requires pydantic>=2.11.7, but you have pydantic 2.10.6 which is incompatible.
# unsloth-zoo 2026.4.6 requires datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1, but you have datasets 4.8.4 which is incompatible.
# unsloth-zoo 2026.4.6 requires transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3, but you have transformers 5.5.3 which is incompatible.
# unsloth-zoo 2026.4.6 requires trl!=0.19.0,<=0.24.0,>=0.18.2, but you have trl 1.0.0 which is incompatible.
# rasterio 1.5.0 requires click!=8.2.*,>=4.0, but you have click 8.2.1 which is incompatible.
# mcp 1.26.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 2.10.6 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.0 which is incompatible.
# google-adk 1.28.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.0 which is incompatible.
# google-adk 1.28.0 requires pydantic<3.0.0,>=2.12.0, but you have pydantic 2.10.6 which is incompatible.
# Successfully installed accelerate-1.6.0 click-8.2.1 datasets-4.8.4 hf-xet-1.4.3 huggingface_hub-1.10.1 immutables-0.21 mergekit-0.1.4 pydantic-2.10.6 pydantic-core-2.27.2 safetensors-0.5.3 tqdm-4.67.1 transformers-5.5.3 trl-1.0.0
# Collecting flashinfer-cubin==0.6.4
#   Downloading flashinfer_cubin-0.6.4-py3-none-any.whl.metadata (1.3 kB)
# Downloading flashinfer_cubin-0.6.4-py3-none-any.whl (245.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.7/245.7 MB 5.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: flashinfer-cubin
#   Attempting uninstall: flashinfer-cubin
#     Found existing installation: flashinfer-cubin 0.6.6
#     Uninstalling flashinfer-cubin-0.6.6:
#       Successfully uninstalled flashinfer-cubin-0.6.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.19.0 requires flashinfer-cubin==0.6.6, but you have flashinfer-cubin 0.6.4 which is incompatible.
# vllm 0.19.0 requires pydantic>=2.12.0, but you have pydantic 2.10.6 which is incompatible.
# vllm 0.19.0 requires transformers<5,>=4.56.0, but you have transformers 5.5.3 which is incompatible.
# Successfully installed flashinfer-cubin-0.6.4

# %% [markdown]
# # For Instrucct models

# %%
# 1. UNSLOTH MUST BE IMPORTED FIRST
from unsloth import FastLanguageModel

# 2. Then import everything else
import os
import re
import sys
import json
import tempfile
import subprocess
from datasets import load_dataset
from transformers import TrainerCallback
from trl import GRPOConfig, GRPOTrainer

max_seq_length = 2048

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Qwen2.5-0.5B-Instruct",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    fast_inference=False, # <--- SET THIS TO FALSE
)



max_seq_length = 2048

model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
    use_rslora=False,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)

# ==========================================
# 2. DATASET PREPARATION
# ==========================================
def format_dataset(row):
    # Parse the codeforces examples JSON string into inputs and outputs
    try:
        examples = json.loads(row['examples'])
        input_tests = [str(ex['input']) for ex in examples]
        output_tests = [str(ex['output']) for ex in examples]
    except Exception:
        input_tests = []
        output_tests = []

    question_level = row['id'].split('/')[-1] if '/' in row['id'] else ""

    return {
        "prompt": [{"role": "user", "content": row['prompt']}], # TRL expects ChatML format
        "input_tests": input_tests,
        "output_tests": output_tests,
        "question_level": question_level
    }

print("Loading and filtering dataset...")
# Load dataset and filter for 'A' questions
dataset = load_dataset("open-r1/codeforces-cots", split="train[:100]")

# Filter for question A and apply formatting
filtered_dataset = dataset.filter(lambda x: x['id'].endswith('A'))
processed_dataset = filtered_dataset.map(format_dataset, num_proc=4)

# Take subset for training
train_dataset = processed_dataset.select(range(min(1000, len(processed_dataset))))

# ==========================================
# 3. REWARD FUNCTIONS (DeepSeek Strategy)
# ==========================================
def format_reward_func(completions, **kwargs):
    """Rewards strict adherence to <think> and markdown code block formatting."""
    rewards = []
    for c in completions:
        # Completions come as a list of dicts or strings depending on TRL version
        content = c[0]['content'] if isinstance(c, list) else c

        has_think = bool(re.search(r"<think>.*?</think>", content, re.DOTALL))
        has_code = bool(re.search(r"```(python|cpp)\n.*?```", content, re.DOTALL))
        rewards.append(0.2 if (has_think and has_code) else 0.0)
    return rewards

def extract_code(completion):
    match = re.search(r"```(python|cpp)\n(.*?)```", completion, re.DOTALL)
    if match:
        return match.group(1), match.group(2)
    return None, None

def run_code(code, lang, inp):
    with tempfile.TemporaryDirectory() as tmp:
        if lang == "cpp":
            cpp = os.path.join(tmp, "sol.cpp")
            exe = os.path.join(tmp, "sol")
            with open(cpp, "w") as f: f.write(code)

            if subprocess.run(["g++", "-O2", cpp, "-o", exe], capture_output=True).returncode != 0:
                return None, "ce" # Compilation Error
            cmd = [exe]
        else:
            py = os.path.join(tmp, "sol.py")
            with open(py, "w") as f: f.write(code)
            cmd = [sys.executable, py]

        try:
            res = subprocess.run(cmd, input=inp, text=True, capture_output=True, timeout=2.0)
            if res.returncode != 0:
                return None, "re" # Runtime Error
            return res.stdout.strip(), "ok"
        except subprocess.TimeoutExpired:
            return None, "tle" # Time Limit Exceeded
        except Exception as e:
            return None, f"error: {str(e)}"

def correctness_reward_func(completions, input_tests, output_tests, **kwargs):
    """Executes the code and scores based on percentage of passed test cases."""
    rewards = []
    for comp, ins, outs in zip(completions, input_tests, output_tests):
        content = comp[0]['content'] if isinstance(comp, list) else comp
        lang, code = extract_code(content)

        if not code or not ins:
            rewards.append(-0.5)
            continue

        score = 0
        total = len(ins)

        for i, o in zip(ins, outs):
            out, status = run_code(code, lang, i)
            if status == "ok" and out == o.strip():
                score += 1

        # Proportional reward based on test cases passed
        rewards.append(score / total if total > 0 else 0.0)

    return rewards

# ==========================================
# 4. TRAINING & LOGGING CALLBACK
# ==========================================
class EpochSaveCallback(TrainerCallback):
    def on_epoch_end(self, args, state, control, **kwargs):
        # Save to the exact same directory, overwriting previous epoch
        save_path = os.path.join(args.output_dir, "latest_epoch_weights")
        print(f"\n[Epoch {state.epoch}] Saving overwritten checkpoint to {save_path}")
        kwargs["model"].save_pretrained(save_path)
        kwargs["tokenizer"].save_pretrained(save_path)

training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 5, # Increased slightly to reduce log spam
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 4,
    num_generations = 4, # GRPO needs a group to compare. 4 is a safe minimum.
    max_prompt_length = 1024,
    max_completion_length = 1024,
    num_train_epochs = 1,
    save_strategy="no", # Handled by our custom callback
    max_grad_norm = 0.1,
    report_to = "none",
    output_dir = "outputs",
    importance_sampling_level = "sequence",
    loss_type = "dr_grpo",
)

trainer = GRPOTrainer(
    model = model,
    args = training_args,
    processing_class = tokenizer,
    reward_funcs = [
        format_reward_func,
        correctness_reward_func,
    ],
    train_dataset = train_dataset,
    callbacks=[EpochSaveCallback()]
)

print("Starting GRPO Training...")
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6357/3987712589.py in <cell line: 0>()
#       1 # 1. UNSLOTH MUST BE IMPORTED FIRST
# ----> 2 from unsloth import FastLanguageModel
#       3
#       4 # 2. Then import everything else
#       5 import os
#
# ModuleNotFoundError: No module named 'unsloth'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# ==========================================
# 5. POST-TRAINING VERIFICATION
# ==========================================
print("\n--- Running Manual Verification ---")
# Pick a question outside our train set (e.g., from the end of the dataset)
val_sample = processed_dataset[-1]

# Format prompt for generation
messages = val_sample["prompt"]
inputs = tokenizer.apply_chat_template(messages, return_tensors="pt", add_generation_prompt=True).to("cuda")

# Generate Code
print(f"Generating solution for Problem: {val_sample['id']}")
outputs = model.generate(
    inputs,
    max_new_tokens=1024,
    pad_token_id=tokenizer.eos_token_id
)

generated_text = tokenizer.decode(outputs[0][inputs.shape[1]:], skip_special_tokens=True)
print("\n--- Generated Output ---")
print(generated_text)
print("------------------------")

# Run through custom reward functions to check outputs manually
format_score = format_reward_func([generated_text])[0]
correctness_score = correctness_reward_func(
    [generated_text],
    [val_sample["input_tests"]],
    [val_sample["output_tests"]]
)[0]

print("\n--- Metrics ---")
print(f"Format Reward  : {format_score}")
print(f"Correctness    : {correctness_score} (Percentage of Test Cases Passed)")

# %% [markdown]
# # for non instruct models

# %%
# 1. UNSLOTH MUST BE IMPORTED FIRST
from unsloth import FastLanguageModel

# 2. Then import everything else
import os
import re
import sys
import json
import tempfile
import subprocess
from datasets import load_dataset
from transformers import TrainerCallback
from trl import GRPOConfig, GRPOTrainer

max_seq_length = 2048

# Use a BASE model instead of an Instruct model
model, tokenizer = FastLanguageModel.from_pretrained(
    # model_name="unsloth/Qwen2.5-0.5B", 
    model_name="unsloth/Qwen3-14B-unsloth-bnb-4bit", 
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    fast_inference=False, # <--- SET THIS TO FALSE
)

# Ensure pad token is set for base models (often required for batched generation)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
    use_rslora=False,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)

# ==========================================
# 2. DATASET PREPARATION
# ==========================================
def format_dataset(row):
    try:
        examples = json.loads(row['examples'])
        input_tests = [str(ex['input']) for ex in examples]
        output_tests = [str(ex['output']) for ex in examples]
    except Exception:
        input_tests = []
        output_tests = []
    
    question_level = row['id'].split('/')[-1] if '/' in row['id'] else ""
    
    # BASE MODEL CHANGE: Use a raw string with strict formatting instead of chat dicts.
    # We explicitly guide the base model on how to format its output.
    raw_prompt = (
        f"You are an expert competitive programmer. Solve the following problem.\n"
        f"Put your reasoning inside <think> </think> tags, and your code inside a markdown block.\n\n"
        f"Problem:\n{row['prompt']}\n\n"
        f"Solution:\n<think>\n"
    )
    
    return {
        "prompt": raw_prompt,
        "input_tests": input_tests,
        "output_tests": output_tests,
        "question_level": question_level
    }

print("Loading and filtering dataset...")
# Load dataset and filter for 'A' questions
dataset = load_dataset("open-r1/codeforces-cots", split="train[:1000]")

filtered_dataset = dataset.filter(lambda x: x['id'].endswith('A'))
processed_dataset = filtered_dataset.map(format_dataset, num_proc=4)

train_dataset = processed_dataset.select(range(min(1000, len(processed_dataset))))

# ==========================================
# 3. REWARD FUNCTIONS
# ==========================================
def format_reward_func(completions, **kwargs):
    rewards = []
    for c in completions:
        # TRL passes string completions for base string prompts
        content = c[0]['content'] if isinstance(c, list) else c
        
        has_think = bool(re.search(r"<think>.*?</think>", content, re.DOTALL))
        has_code = bool(re.search(r"```(python|cpp)\n.*?```", content, re.DOTALL))
        rewards.append(0.2 if (has_think and has_code) else 0.0)
    return rewards

def extract_code(completion):
    match = re.search(r"```(python|cpp)\n(.*?)```", completion, re.DOTALL)
    if match:
        return match.group(1), match.group(2)
    return None, None

def run_code(code, lang, inp):
    with tempfile.TemporaryDirectory() as tmp:
        if lang == "cpp":
            cpp = os.path.join(tmp, "sol.cpp")
            exe = os.path.join(tmp, "sol")
            with open(cpp, "w") as f: f.write(code)

            if subprocess.run(["g++", "-O2", cpp, "-o", exe], capture_output=True).returncode != 0:
                return None, "ce"
            cmd = [exe]
        else:
            py = os.path.join(tmp, "sol.py")
            with open(py, "w") as f: f.write(code)
            cmd = [sys.executable, py]

        try:
            res = subprocess.run(cmd, input=inp, text=True, capture_output=True, timeout=2.0)
            if res.returncode != 0:
                return None, "re"
            return res.stdout.strip(), "ok"
        except subprocess.TimeoutExpired:
            return None, "tle"
        except Exception as e:
            return None, f"error: {str(e)}"

def correctness_reward_func(completions, input_tests, output_tests, **kwargs):
    rewards = []
    for comp, ins, outs in zip(completions, input_tests, output_tests):
        content = comp[0]['content'] if isinstance(comp, list) else comp
        lang, code = extract_code(content)

        if not code or not ins:
            rewards.append(-0.5)
            continue

        score = 0
        total = len(ins)

        for i, o in zip(ins, outs):
            out, status = run_code(code, lang, i)
            if status == "ok" and out == o.strip():
                score += 1
                
        rewards.append(score / total if total > 0 else 0.0)

    return rewards

# ==========================================
# 4. TRAINING & LOGGING CALLBACK
# ==========================================
class EpochSaveCallback(TrainerCallback):
    def on_epoch_end(self, args, state, control, **kwargs):
        save_path = os.path.join(args.output_dir, "latest_epoch_weights")
        print(f"\n[Epoch {state.epoch}] Saving overwritten checkpoint to {save_path}")
        kwargs["model"].save_pretrained(save_path)
        kwargs["tokenizer"].save_pretrained(save_path)
    

training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 4, 
    num_generations = 4,
    max_prompt_length = 1024,
    max_completion_length = 1024,
    num_train_epochs = 1,
    save_strategy="no",
    max_grad_norm = 0.1,
    report_to = "none",
    output_dir = "outputs",
    importance_sampling_level = "sequence",
    loss_type = "dr_grpo",
)

trainer = GRPOTrainer(
    model = model,
    args = training_args,
    processing_class = tokenizer,
    reward_funcs = [
        format_reward_func,
        correctness_reward_func,
    ],
    train_dataset = train_dataset,
    callbacks=[EpochSaveCallback()]
)

print("Starting GRPO Training...")
trainer.train()
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6357/3511630638.py in <cell line: 0>()
#       1 # 1. UNSLOTH MUST BE IMPORTED FIRST
# ----> 2 from unsloth import FastLanguageModel
#       3
#       4 # 2. Then import everything else
#       5 import os
#
# /usr/local/lib/python3.12/dist-packages/unsloth/__init__.py in <module>
#     309     pass
#     310
# --> 311 from .models import *
#     312 from .models import __version__
#     313 from .save import *
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/__init__.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from .llama import FastLlamaModel
#      16 from .loader import FastLanguageModel, FastVisionModel, FastTextModel, FastModel
#      17 from .mistral import FastMistralModel
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in <module>
#      19 from typing import Optional, Tuple, List, Union
#      20
# ---> 21 from ._utils import *
#      22 from ._utils import apply_unsloth_gradient_checkpointing
#      23 from ._utils import __version__, importlib_version
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in <module>
#     310
#     311
# --> 312 _run_temporary_patches("init")
#     313
#     314 # =============================================
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in _run_temporary_patches(phase)
#     305                 temporary_patch(phase = phase)
#     306             else:
# --> 307                 temporary_patch()
#     308         except (ValueError, TypeError):
#     309             temporary_patch()
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/temporary_patches/misc.py in patch_vllm_safe_apply_chat_template()
#    1269             return
#    1270
# -> 1271         import vllm.renderers.hf as hf_mod
#    1272         _original_safe_apply = getattr(hf_mod, "safe_apply_chat_template", None)
#    1273         if _original_safe_apply is None:
#
# /usr/local/lib/python3.12/dist-packages/vllm/renderers/__init__.py in <module>
#       2 # SPDX-FileCopyrightText: Copyright contributors to the vLLM project
#       3
# ----> 4 from .base import BaseRenderer
#       5 from .params import ChatParams, TokenizeParams, merge_kwargs
#       6 from .registry import RendererRegistry, renderer_from_config
#
# /usr/local/lib/python3.12/dist-packages/vllm/renderers/base.py in <module>
#      46 from vllm.utils.counter import AtomicCounter
#      47 from vllm.utils.torch_utils import set_default_torch_num_threads
# ---> 48 from vllm.v1.metrics.stats import MultiModalCacheStats
#      49
#      50 from .embed_utils import safe_load_prompt_embeds
#
# /usr/local/lib/python3.12/dist-packages/vllm/v1/metrics/stats.py in <module>
#       8
#       9 import vllm.envs as envs
# ---> 10 from vllm.compilation.cuda_graph import CUDAGraphStat
#      11 from vllm.v1.metrics.perf import PerfStats
#      12 from vllm.v1.spec_decode.metrics import SpecDecodingStats
#
# /usr/local/lib/python3.12/dist-packages/vllm/compilation/cuda_graph.py in <module>
#      16 from vllm.compilation.monitor import validate_cudagraph_capturing_enabled
#      17 from vllm.config import CUDAGraphMode, VllmConfig
# ---> 18 from vllm.distributed.device_communicators.pynccl_allocator import set_graph_pool_id
#      19 from vllm.forward_context import (
#      20     BatchDescriptor,
#
# /usr/local/lib/python3.12/dist-packages/vllm/distributed/device_communicators/pynccl_allocator.py in <module>
#       9 from packaging import version
#      10 from torch.cuda.memory import CUDAPluggableAllocator
# ---> 11 from torch.utils.cpp_extension import load_inline
#      12
#      13 from vllm import envs
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py in <module>
#      28
#      29
# ---> 30 from setuptools.command.build_ext import build_ext
#      31
#      32 IS_WINDOWS = sys.platform == 'win32'
#
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_ext.py in <module>
#      30         # Additionally, assert that the compiler module will load
#      31         # also. Ref #1229.
# ---> 32         __import__('Cython.Compiler.Main')
#      33     except ImportError:
#      34         from distutils.command.build_ext import build_ext as _build_ext
#
# /usr/local/lib/python3.12/dist-packages/Cython/Compiler/Main.py in <module>
#      26 from . import Errors
#      27 from .StringEncoding import EncodedString
# ---> 28 from .Scanning import PyrexScanner, FileSourceDescriptor
#      29 from .Errors import PyrexError, CompileError, error, warning
#      30 from .Symtab import ModuleScope
#
# /usr/local/lib/python3.12/dist-packages/Cython/Compiler/Scanning.cpython-312-x86_64-linux-gnu.so in init Cython.Compiler.Scanning()
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# ==========================================
# 5. POST-TRAINING VERIFICATION
# ==========================================
print("\n--- Running Manual Verification ---")
val_sample = processed_dataset[-1]

# BASE MODEL CHANGE: Use direct text tokenization instead of apply_chat_template
prompt_text = val_sample["prompt"]
inputs = tokenizer(prompt_text, return_tensors="pt").to("cuda")

print(f"Generating solution for Problem: {val_sample['id']}")
outputs = model.generate(
    **inputs, 
    max_new_tokens=1024, 
    pad_token_id=tokenizer.pad_token_id
)

# Decode only the generated portion
generated_text = tokenizer.decode(outputs[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True)

print("\n--- Generated Output ---")
print(generated_text)
print("------------------------")

format_score = format_reward_func([generated_text])[0]
correctness_score = correctness_reward_func(
    [generated_text], 
    [val_sample["input_tests"]], 
    [val_sample["output_tests"]]
)[0]

print("\n--- Metrics ---")
print(f"Format Reward  : {format_score}")
print(f"Correctness    : {correctness_score} (Percentage of Test Cases Passed)")
